# %%
import pandas as pd
import plotly.graph_objects as go
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
# Out:
# C:\Users\orteg\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\orteg\anaconda3\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\orteg\anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# ## Loading and Checking the Data

# %%
df = pd.read_csv('accepted_only_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  loan_amnt               title  fico_range_low  fico_range_high  \
# 0           0     3600.0  Debt consolidation             675              679
# 1           1    24700.0            Business             715              719
# 2           2    35000.0  Debt consolidation             785              789
# 3           3    10400.0      Major purchase             695              699
# 4           4    11950.0  Debt consolidation             690              694
#
#      dti zip_code addr_state emp_length                    emp_title  \
# 0   5.91    190xx         PA  10+ years                      leadman
# 1  16.06    577xx         SD  10+ years                     Engineer
# 2  17.06    076xx         NJ  10+ years  Information Systems Officer
# 3  25.37    174xx         PA    3 years          Contract Specialist
# 4  10.20    300xx         GA    4 years         Veterinary Tecnician
#
#    funded_amnt hardship_flag home_ownership loan_status application_type  \
# 0       3600.0             N       MORTGAGE  Fully Paid       Individual
# 1      24700.0             N       MORTGAGE  Fully Paid       Individual
# 2      35000.0             N       MORTGAGE     Current       Individual
# 3      10400.0             N       MORTGAGE  Fully Paid       Individual
# 4      11950.0             N           RENT  Fully Paid       Individual
#
#     issue_d  policy_code  Applicant_Result  int_rate
# 0  Dec-2015            1                 1     13.99
# 1  Dec-2015            1                 1     11.99
# 2  Dec-2015            1                 1     14.85
# 3  Dec-2015            1                 1     22.45
# 4  Dec-2015            1                 1     13.44

# %%
df = df.drop(['Unnamed: 0'], axis = 1)

# %%
df.head()
# Out:
#    loan_amnt               title  fico_range_low  fico_range_high    dti  \
# 0     3600.0  Debt consolidation             675              679   5.91
# 1    24700.0            Business             715              719  16.06
# 2    35000.0  Debt consolidation             785              789  17.06
# 3    10400.0      Major purchase             695              699  25.37
# 4    11950.0  Debt consolidation             690              694  10.20
#
#   zip_code addr_state emp_length                    emp_title  funded_amnt  \
# 0    190xx         PA  10+ years                      leadman       3600.0
# 1    577xx         SD  10+ years                     Engineer      24700.0
# 2    076xx         NJ  10+ years  Information Systems Officer      35000.0
# 3    174xx         PA    3 years          Contract Specialist      10400.0
# 4    300xx         GA    4 years         Veterinary Tecnician      11950.0
#
#   hardship_flag home_ownership loan_status application_type   issue_d  \
# 0             N       MORTGAGE  Fully Paid       Individual  Dec-2015
# 1             N       MORTGAGE  Fully Paid       Individual  Dec-2015
# 2             N       MORTGAGE     Current       Individual  Dec-2015
# 3             N       MORTGAGE  Fully Paid       Individual  Dec-2015
# 4             N           RENT  Fully Paid       Individual  Dec-2015
#
#    policy_code  Applicant_Result  int_rate
# 0            1                 1     13.99
# 1            1                 1     11.99
# 2            1                 1     14.85
# 3            1                 1     22.45
# 4            1                 1     13.44

# %%
df[['issue_month', 'issue_year']] = df.issue_d.str.split("-", expand = True)

# %%
df.head()
# Out:
#    loan_amnt               title  fico_range_low  fico_range_high    dti  \
# 0     3600.0  Debt consolidation             675              679   5.91
# 1    24700.0            Business             715              719  16.06
# 2    35000.0  Debt consolidation             785              789  17.06
# 3    10400.0      Major purchase             695              699  25.37
# 4    11950.0  Debt consolidation             690              694  10.20
#
#   zip_code addr_state emp_length                    emp_title  funded_amnt  \
# 0    190xx         PA  10+ years                      leadman       3600.0
# 1    577xx         SD  10+ years                     Engineer      24700.0
# 2    076xx         NJ  10+ years  Information Systems Officer      35000.0
# 3    174xx         PA    3 years          Contract Specialist      10400.0
# 4    300xx         GA    4 years         Veterinary Tecnician      11950.0
#
#   hardship_flag home_ownership loan_status application_type   issue_d  \
# 0             N       MORTGAGE  Fully Paid       Individual  Dec-2015
# 1             N       MORTGAGE  Fully Paid       Individual  Dec-2015
# 2             N       MORTGAGE     Current       Individual  Dec-2015
# 3             N       MORTGAGE  Fully Paid       Individual  Dec-2015
# 4             N           RENT  Fully Paid       Individual  Dec-2015
#
#    policy_code  Applicant_Result  int_rate issue_month issue_year
# 0            1                 1     13.99         Dec       2015
# 1            1                 1     11.99         Dec       2015
# 2            1                 1     14.85         Dec       2015
# 3            1                 1     22.45         Dec       2015
# 4            1                 1     13.44         Dec       2015

# %% [markdown]
# ## Trying to Graph

# %% [markdown]
# Values 2015 and after have been significantly reduced. I assume that means the free write option has been removed and a list is given.

# %%
df['title'].value_counts()
# Out:
# Debt consolidation           1071649
# Credit card refinancing       434772
# Home improvement              125079
# Other                         116275
# Major purchase                 41571
#                               ...
# Paying it Forward~                 1
# final credit card pay off          1
# Short-term investment              1
# Old home loan                      1
# Credit Card Financing              1
# Name: title, Length: 59289, dtype: int64

# %%
df['issue_year'] = df['issue_year'].astype("int64")

# %% [markdown]
# # NLP

# %%
home = ['home', 'house', 'kitchen', 'improvement', 'pool', 'remodel']
car = ['car', 'auto', 'motorcycle', 'vehicle', 'truck']
business = ['business']
medical = ['medical', 'remove']
debt_credit_issues = ['consolidation', 'credit', 'debt', 'refinancing', 'card', 'cc', 'consolidate', 'payoff', 
                      'interest', 'rate'] 
moving = ['move', 'moving']
major_purchase = ['purchase', 'major']
vacation = ['vacation']
wedding = ['wedding', 'ring']
student = ['student', 'college', 'education', 'school']
#If not categories match, then it will be placed into the 'other' category

# %%
df["reduced_reason"] = "Test"

# %%
df['title'] = df['title'].apply(str.lower)

# %%
my_dict = {"Home": home, "Car": car, "Business": business, "Medical": medical, "Vacation": vacation, "Wedding": wedding,
        "Moving": moving, "Student": student, "Major Purchase": major_purchase, "Debt/Credit Issues": debt_credit_issues}

# %%
for k, v in my_dict.items():
    for word in v:
        df.loc[df['title'].str.contains(word), 'reduced_reason'] = k

# %%
df['reduced_reason'][df['reduced_reason'] == "Test"] = "Other"
# Out:
# C:\Users\orteg\AppData\Local\Temp\ipykernel_36376\57583683.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['reduced_reason'][df['reduced_reason'] == "Test"] = "Other"

# %%
df['reduced_reason'].value_counts()
# Out:
# Debt/Credit Issues    1615026
# Other                  170222
# Home                   146473
# Major Purchase          42914
# Medical                 23935
# Car                     21831
# Business                21160
# Moving                  13964
# Vacation                13785
# Wedding                  2733
# Student                   662
# Name: reduced_reason, dtype: int64

# %%
df['title'][df['reduced_reason']=='Other'].value_counts()
# Out:
# other                               116355
# personal loan                         3162
# personal                              1881
# loan                                  1510
# freedom                               1183
#                                      ...
# i want to graduate on time!              1
# purchasing landscape cad program         1
# hfcscrewedme                             1
# ford torres                              1
# 3yr conolidation                         1
# Name: title, Length: 22159, dtype: int64

# %%
simple_df = df[['reduced_reason', 'issue_month', 'issue_year']]

# %%
group_dates = simple_df.groupby(['issue_year', 'issue_month', 
                                 'reduced_reason']).size()

# %%
group_dates = pd.DataFrame(group_dates, columns=['count'])

# %%
group_dates.reset_index(inplace=True)

# %%
group_dates.head(10)
# Out:
#    issue_year issue_month      reduced_reason  count
# 0        2007         Aug            Business      1
# 1        2007         Aug                 Car      3
# 2        2007         Aug  Debt/Credit Issues     31
# 3        2007         Aug                Home      4
# 4        2007         Aug              Moving      2
# 5        2007         Aug               Other     18
# 6        2007         Aug             Student      4
# 7        2007         Aug            Vacation      1
# 8        2007         Aug             Wedding      1
# 9        2007         Dec            Business      5

# %%
group_dates['month'] = ""

# %%
group_dates['month'][group_dates['issue_month']=="Aug"] = "August"
group_dates['month'][group_dates['issue_month']=="Jan"] = "January"
group_dates['month'][group_dates['issue_month']=="Feb"] = "February"
group_dates['month'][group_dates['issue_month']=="Mar"] = "March"
group_dates['month'][group_dates['issue_month']=="Apr"] = "April"
group_dates['month'][group_dates['issue_month']=="May"] = "May"
group_dates['month'][group_dates['issue_month']=="Jun"] = "June"
group_dates['month'][group_dates['issue_month']=="Jul"] = "July"
group_dates['month'][group_dates['issue_month']=="Sep"] = "September"
group_dates['month'][group_dates['issue_month']=="Oct"] = "October"
group_dates['month'][group_dates['issue_month']=="Nov"] = "November"
group_dates['month'][group_dates['issue_month']=="Dec"] = "December"
# Out:
# C:\Users\orteg\AppData\Local\Temp\ipykernel_36376\3373904084.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_dates['month'][group_dates['issue_month']=="Aug"] = "August"
# C:\Users\orteg\AppData\Local\Temp\ipykernel_36376\3373904084.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_dates['month'][group_dates['issue_month']=="Jan"] = "January"
# C:\Users\orteg\AppData\Local\Temp\ipykernel_36376\3373904084.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_dates['month'][group_dates['issue_month']=="Feb"] = "February"
# C:\Users\orteg\AppData\Local\Temp\ipykernel_36376\3373904084.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_dates['month'][group_dates['issue_month']=="Mar"] = "March"
# C:\Users\orteg\AppData\Local\Temp\ipykernel_36376\3373904084.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_dates['month'][group_dates['issue_month']=="Apr"] = "April"
# C:\Users\orteg\AppData\Local\Temp\ipykernel_36376\3373904084.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_dates['month'][group_dates['issue_month']=="May"] = "May"
# C:\Users\orteg\AppData\Local\Temp\ipykernel_36376\3373904084.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_dates['month'][group_dates['issue_month']=="Jun"] = "June"
# C:\Users\orteg\AppData\Local\Temp\ipykernel_36376\3373904084.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_dates['month'][group_dates['issue_month']=="Jul"] = "July"
# C:\Users\orteg\AppData\Local\Temp\ipykernel_36376\3373904084.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_dates['month'][group_dates['issue_month']=="Sep"] = "September"
# C:\Users\orteg\AppData\Local\Temp\ipykernel_36376\3373904084.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_dates['month'][group_dates['issue_month']=="Oct"] = "October"
# C:\Users\orteg\AppData\Local\Temp\ipykernel_36376\3373904084.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_dates['month'][group_dates['issue_month']=="Nov"] = "November"
# C:\Users\orteg\AppData\Local\Temp\ipykernel_36376\3373904084.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_dates['month'][group_dates['issue_month']=="Dec"] = "December"

# %%
group_dates.head()
# Out:
#    issue_year issue_month      reduced_reason  count   month
# 0        2007         Aug            Business      1  August
# 1        2007         Aug                 Car      3  August
# 2        2007         Aug  Debt/Credit Issues     31  August
# 3        2007         Aug                Home      4  August
# 4        2007         Aug              Moving      2  August

# %%
from calendar import month_name
month_lookup = list(month_name)

# %%
group_dates['month'] = pd.Categorical(group_dates['month'], categories=month_lookup, ordered=True)

# %%
group_dates.sort_values(by=['month', 'reduced_reason'],inplace=True)

# %%
# %pip install kaleido
# Out:
# Requirement already satisfied: kaleido in c:\users\orteg\anaconda3\lib\site-packages (0.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.io as pio
import plotly.express as px
import numpy as np

# %%
fig = px.bar_polar(group_dates, r="count",theta='issue_month',
                   color="reduced_reason", labels={"reduced_reason": "Loan Types"})

fig.update_layout(legend=dict(
    yanchor="top",
    y=0.80,
    xanchor="left",
    x=1.1,
    bgcolor="LightGray",
    bordercolor="Black",
    borderwidth=1),font=dict(
        size=50)#,
    #title={
    #'text': "Distribution of Loan Types by Month",
    #'y':0.99999,
    #'x':0.45,
    #'xanchor': 'center',
    #'yanchor': 'top'}
                 )
fig.update_polars(radialaxis_nticks=11)
fig.update_polars(angularaxis_tickfont_size=50)
fig.update_polars(radialaxis_tickfont_size=60)
fig.update_polars(radialaxis_angle=70)
fig.update_polars(radialaxis_tickangle=90)
config = {
  'toImageButtonOptions': {
    'format': 'png', # one of png, svg, jpeg, webp
    'filename': 'custom_image',
    'height': 1680,
    'width': 2380,
    'scale':5 # Multiply title/legend/axis/canvas sizes by this factor
  }
}
fig.show(config=config)
#pio.write_image(fig, 'Rose_Graph.png', scale=10, width=1980, height=1080)
# Out:
# <div>                            <div id="4c128940-ce82-41a8-b58e-3cb7e7e6e870" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c128940-ce82-41a8-b58e-3cb7e7e6e870")) {                    Plotly.newPlot(                        "4c128940-ce82-41a8-b58e-3cb7e7e6e870",                        [{"hovertemplate":"Loan Types=Business<br>count=%{r}<br>issue_month=%{theta}<extra></extra>","legendgroup":"Business","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Business","r":[8,2,6,28,73,49,136,263,296,384,449,12,4,11,26,66,58,131,228,334,327,422,14,17,11,33,66,68,158,215,608,400,423,17,15,10,29,68,61,195,275,354,301,417,5,11,9,43,80,80,159,180,332,381,446,3,11,9,33,70,69,160,224,322,321,330,1,4,9,13,42,89,77,254,283,324,354,288,1,6,12,10,53,93,81,152,270,323,441,283,1,5,10,26,57,73,113,92,226,315,424,241,6,3,9,14,59,76,78,323,351,351,424,214,8,13,9,20,54,75,96,216,275,340,513,196,5,8,10,21,56,57,113,110,452,487,515,211],"showlegend":true,"subplot":"polar","theta":["Jan","Jan","Jan","Jan","Jan","Jan","Jan","Jan","Jan","Jan","Jan","Feb","Feb","Feb","Feb","Feb","Feb","Feb","Feb","Feb","Feb","Feb","Mar","Mar","Mar","Mar","Mar","Mar","Mar","Mar","Mar","Mar","Mar","Apr","Apr","Apr","Apr","Apr","Apr","Apr","Apr","Apr","Apr","Apr","May","May","May","May","May","May","May","May","May","May","May","Jun","Jun","Jun","Jun","Jun","Jun","Jun","Jun","Jun","Jun","Jun","Jul","Jul","Jul","Jul","Jul","Jul","Jul","Jul","Jul","Jul","Jul","Jul","Aug","Aug","Aug","Aug","Aug","Aug","Aug","Aug","Aug","Aug","Aug","Aug","Sep","Sep","Sep","Sep","Sep","Sep","Sep","Sep","Sep","Sep","Sep","Sep","Oct","Oct","Oct","Oct","Oct","Oct","Oct","Oct","Oct","Oct","Oct","Oct","Nov","Nov","Nov","Nov","Nov","Nov","Nov","Nov","Nov","Nov","Nov","Nov","Dec","Dec","Dec","Dec","Dec","Dec","Dec","Dec","Dec","Dec","Dec","Dec"],"type":"barpolar"},{"hovertemplate":"Loan Types=Car<br>count=%{r}<br>issue_month=%{theta}<extra></extra>","legendgroup":"Car","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Car","r":[9,11,12,42,47,50,117,213,259,330,398,9,6,14,55,40,56,102,185,344,298,351,6,26,18,66,55,69,107,187,557,414,486,2,21,21,59,46,67,121,294,352,352,477,1,13,25,68,78,90,160,231,272,438,505,11,17,34,63,45,81,136,237,366,452,420,3,9,15,41,61,69,92,221,392,407,433,325,3,2,24,47,60,88,125,144,253,371,535,337,3,1,17,34,74,73,98,99,217,325,411,274,2,2,17,37,60,73,103,281,410,376,425,311,2,4,12,39,56,68,97,170,287,319,445,282,3,6,18,38,46,46,105,81,373,372,411,277],"showlegend":true,"subplot":"polar","theta":["Jan","Jan","Jan","Jan","Jan","Jan","Jan","Jan","Jan","Jan","Jan","Feb","Feb","Feb","Feb","Feb","Feb","Feb","Feb","Feb","Feb","Feb","Mar","Mar","Mar","Mar","Mar","Mar","Mar","Mar","Mar","Mar","Mar","Apr","Apr","Apr","Apr","Apr","Apr","Apr","Apr","Apr","Apr","Apr","May","May","May","May","May","May","May","May","May","May","May","Jun","Jun","Jun","Jun","Jun","Jun","Jun","Jun","Jun","Jun","Jun","Jul","Jul","Jul","Jul","Jul","Jul","Jul","Jul","Jul","Jul","Jul","Jul","Aug","Aug","Aug","Aug","Aug","Aug","Aug","Aug","Aug","Aug","Aug","Aug","Sep","Sep","Sep","Sep","Sep","Sep","Sep","Sep","Sep","Sep","Sep","Sep","Oct","Oct","Oct","Oct","Oct","Oct","Oct","Oct","Oct","Oct","Oct","Oct","Nov","Nov","Nov","Nov","Nov","Nov","Nov","Nov","Nov","Nov","Nov","Nov","Dec","Dec","Dec","Dec","Dec","Dec","Dec","Dec","Dec","Dec","Dec","Dec"],"type":"barpolar"},{"hovertemplate":"Loan Types=Debt/Credit Issues<br>count=%{r}<br>issue_month=%{theta}<extra></extra>","legendgroup":"Debt/Credit Issues","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Debt/Credit Issues","r":[107,125,214,625,1452,4605,11644,28753,23221,23606,24923,155,128,265,555,1473,5125,11813,19137,27772,20181,22124,191,113,293,554,1519,5335,13161,20250,42656,26767,25741,128,96,342,6 ...

# %%
group_dates.head()
# Out:
#      issue_year issue_month reduced_reason  count    month
# 96         2008         Jan       Business      8  January
# 216        2009         Jan       Business      2  January
# 345        2010         Jan       Business      6  January
# 476        2011         Jan       Business     28  January
# 608        2012         Jan       Business     73  January

# %%
group_dates.groupby(['issue_month', 'reduced_reason'])[['count']].sum()
# Out:
#                                  count
# issue_month reduced_reason
# Apr         Business              1742
#             Car                   1812
#             Debt/Credit Issues  125518
#             Home                 13295
#             Major Purchase        3728
# ...                                ...
# Sep         Moving                1138
#             Other                13364
#             Student                 58
#             Vacation               925
#             Wedding                290
#
# [132 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

# %%
group_dates.groupby(['issue_month', 'reduced_reason'])[['count']].sum().unstack().plot(kind='barh')
plt.xlim(0, 25000)
plt.show()

# %% [markdown]
# ## Make an animation of this?
